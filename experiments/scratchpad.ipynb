# %%
    # !modal run llmlingua2_modal.py
# Out:
# /Users/mohak/.zshenv:1: bad assignment
# ✓ Initialized. View run at
# https://modal.com/apps/mohakprakash2016/main/ap-cy6hD0ggh6JbyF8G6J8Cgn
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Uploaded
# ⠦ Creating objects...
# └── ⠸ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Uploaded
# Building image im-yoAn1Vt28yplkm4NUBWP9C
# ⠧ Creating objects...
# m⠼ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Uploaded
# => Step 0: FROM base
# ⠇ Creating objects...
# m⠴ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Finalizi
# => Step 1: RUN python -m pip install huggingface_hub llmlingua torch
# ⠏ Creating objects...
# ⠏ Creating objects...t /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Finalizi
# └── ⠦ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py:
# ⠹ Creating objects...
# ⠴ Creating objects.../Desktop/berkAI26/llmlingua2_modal.py
# ...

# %%
# !modal run llmlingua2_modal.py 2>/dev/null
# Out:
# /Users/mohak/.zshenv:1: bad assignment
# ✓ Initialized. View run at
# https://modal.com/apps/mohakprakash2016/main/ap-AFEco8QdQayXLzXo1hLGHb
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py:
# ⠦ Creating objects...
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# ⠏ Creating objects....
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# ├── 🔨 Created function _download_weights.
# ⠋ Creating objects...
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# ├── 🔨 Created function _download_weights.
# └── 🔨 Created function Compressor.*.
# ✓ Created objects.
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# ├── 🔨 Created function _download_weights.
# └── 🔨 Created function Compressor.*.
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at hLGHb
# ⠴ Running... View app at ayXLzXo1hLGHb
# ...

# %%
SAMPLE = (
    "The committee convened on Tuesday to review the proposed budget allocations "
    "for the upcoming fiscal year. After a lengthy discussion that touched on "
    "several departmental requests, the members agreed to defer the final vote "
    "until additional documentation could be gathered from the finance office, "
    "which had not yet submitted its quarterly projections."
)

committee convened Tuesday review proposed budget allocations upcoming fiscal 
year. discussion, members agreed defer final vote until additional documentation
finance office, submitted quarterly projections.

# %%
# !modal run llmlingua2_modal.py
# Out:
# /Users/mohak/.zshenv:1: bad assignment
# ✓ Initialized. View run at
# https://modal.com/apps/mohakprakash2016/main/ap-fj1F64eW7NBZPII9MbQFoZ
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Uploaded
# ⠦ Creating objects...
# └── ⠸ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Uploaded
# Building image im-JD7HYqAJTBvnqLnfcZO8op
# ⠧ Creating objects...
# m⠼ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Finalizi
# => Step 0: FROM base
# ⠇ Creating objects...
# m⠴ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py: Finalizi
# => Step 1: RUN python -m pip install hf_transfer huggingface_hub llmlingua torch
# ⠇ Creating objects...
# ⠏ Creating objects...mohak/Desktop/berkAI26/llmlingua2_modal.py
# ⠹ Creating objects.../Desktop/berkAI26/llmlingua2_modal.py
# ⠴ Creating objects.../Desktop/berkAI26/llmlingua2_modal.py
# ...

# %%
# !modal volume ls llmlingua2-hf-cache
# Out:
# /Users/mohak/.zshenv:1: bad assignment
#         Directory listing of '/' in 'llmlingua2-hf-cache'
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Filename              ┃ Type ┃ Created/Modified     ┃ Size    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ xet                   │ dir  │ 2026-06-21 00:14 PDT │ 37 B    │
# │ hub                   │ dir  │ 2026-06-21 00:14 PDT │ 78 B    │
# │ .agent_harnesses.json │ file │ 2026-06-21 00:14 PDT │ 5.1 KiB │
# └───────────────────────┴──────┴──────────────────────┴─────────┘

# %%
# !modal run llmlingua2_modal.py --rate 0.33
# Out:
# /Users/mohak/.zshenv:1: bad assignment
# ✓ Initialized. View run at
# https://modal.com/apps/mohakprakash2016/main/ap-6rhtDHoPToDXwu45Arkkyi
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py:
# ⠦ Creating objects...
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# ⠧ Creating objects...
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# └── 🔨 Created function Compressor.*.
# ✓ Created objects.
# ├── 🔨 Created mount /Users/mohak/Desktop/berkAI26/llmlingua2_modal.py
# └── 🔨 Created function Compressor.*.
# ⠴ Worker assigned... View app at
# ⠏ Running... View app at oDXwu45Arkkyi
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ...
